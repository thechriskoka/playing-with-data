# %%
import pandas as pd
iris = pd.read_csv('iris-flower-dataset/IRIS.csv')
print(iris.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
wine_reviews = pd.read_csv('wine-reviews/winemag-data-130k-v2.csv', index_col=0)
wine_reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
import matplotlib.pyplot as plt
#used for creating good basic graphs

# %%
#creating a scatter plot using our iris data set

#create a figure and axis
fig, ax = plt.subplots()

#scatter the sepal_length against sepal_width
ax.scatter(iris['sepal_length'], iris['sepal_width'])

#set a title and labels
ax.set_title("Iris Dataset")
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
# Out:
# Text(0,0.5,'sepal_width')

# %%
#create color dictionary
colors = {'Iris-setosa':'r', 'Iris-versicolor':'g','Iris-virginica':'b'}

#create a figure and axis
fig, ax = plt.subplots()
#plot each data-point
for i in range(len(iris['sepal_length'])):
    ax.scatter(iris['sepal_length'][i], iris['sepal_width'][i], color=colors[iris['species'][i]])

#set title and legend
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
# Out:
# Text(0,0.5,'sepal_width')

# %%
iris.plot.scatter('sepal_length','sepal_width')

# %%
iris.plot.line()

# %%
wine_reviews['points'].plot.hist()

# %%
iris['sepal_length'].plot.hist()

# %%
iris['sepal_width'].plot.hist()

# %%
iris['petal_length'].plot.hist()

# %%
iris['petal_width'].plot.hist()

# %%
#ploting a bar chart using the plot.bar() method
wine_reviews['points'].value_counts().sort_index().plot.bar()

# %%
#using the above, we can plot a horizontal bar chart
wine_reviews['points'].value_counts().sort_index().plot.barh()

# %%
#ploting with colors
wine_reviews['country'].value_counts().sort_index().plot.bar()

# %%
#intro to seaborn
import seaborn as sns

sns.scatterplot(x='sepal_length',y='sepal_width',hue='class',data=iris)
# Out:
# --------------------------------------------------------------------------
# ImportError                              Traceback (most recent call last)
# <ipython-input-2-9cebfc7b505b> in <module>()
#       1
#       2 #intro to seaborn
# ----> 3 import seaborn as sns
#       4
#       5 sns.scatterplot(x='sepal_length',y='sepal_width',hue='class',data=iris)
#
# ImportError: No module named seaborn
