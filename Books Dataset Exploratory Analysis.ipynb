# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
books= pd.read_csv('books.csv', error_bad_lines=False)
# Out:
# b'Skipping line 4012: expected 10 fields, saw 11\nSkipping line 5688: expected 10 fields, saw 11\nSkipping line 7056: expected 10 fields, saw 11\nSkipping line 10601: expected 10 fields, saw 11\nSkipping line 10668: expected 10 fields, saw 11\n'

# %%
books.shape
# Out:
# (13714, 12)

# %%
print (books.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13714 entries, 0 to 13713
# Data columns (total 12 columns):
# bookID                13714 non-null int64
# title                 13714 non-null object
# authors               13714 non-null object
# average_rating        13714 non-null float64
# isbn                  13714 non-null object
# isbn13                13714 non-null int64
# language_code         13714 non-null object
# # num_pages           13714 non-null int64
# ratings_count         13714 non-null int64
# text_reviews_count    13714 non-null int64
# authors_list          13714 non-null object
# num_author            13714 non-null int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 1.3+ MB
# None

# %%
books.head(50)
# Out:
#     bookID                                              title  \
# 0        1  Harry Potter and the Half-Blood Prince (Harry ...
# 1        2  Harry Potter and the Order of the Phoenix (Har...
# 2        3  Harry Potter and the Sorcerer's Stone (Harry P...
# 3        4  Harry Potter and the Chamber of Secrets (Harry...
# 4        5  Harry Potter and the Prisoner of Azkaban (Harr...
# 5        8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# 6        9  Unauthorized Harry Potter Book Seven News: "Ha...
# 7       10       Harry Potter Collection (Harry Potter  #1-6)
# 8       12  The Ultimate Hitchhiker's Guide: Five Complete...
# 9       13      The Ultimate Hitchhiker's Guide to the Galaxy
# 10      14  The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 11      16  The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 12      18  The Ultimate Hitchhiker's Guide (Hitchhiker's ...
# 13      21               A Short History of Nearly Everything
# 14      22                        Bill Bryson's African Diary
# 15      23  Bryson's Dictionary of Troublesome Words: A Wr...
# 16      24                             In a Sunburned Country
# 17      25  I'm a Stranger Here Myself: Notes on Returning...
# 18      26  The Lost Continent: Travels in Small Town America
# 19      27          Neither Here nor There: Travels in Europe
# 20      28                          Notes from a Small Island
# 21      29  The Mother Tongue: English and How It Got That...
# 22      30  J.R.R. Tolkien 4-Book Boxed Set: The Hobbit an...
# 23      31  The Lord of the Rings (The Lord of the Rings  ...
# 24      32  The Lord of the Rings (The Lord of the Rings  ...
# 25      34  The Fellowship of the Ring (The Lord of the Ri...
# 26      35  The Lord of the Rings (The Lord of the Rings  ...
# 27      36         The Lord of the Rings: Weapons and Warfare
# 28      37   The Lord of the Rings: Complete Visual Companion
# 29      38                      The Lord of the Rings Box Set
# 30      40     Cooking with Fernet Branca (Gerald Samper  #1)
# 31      45  Agile Web Development with Rails: A Pragmatic ...
# 32      50                                            Hatchet
# 33      51  Hatchet: A Guide for Using "Hatchet" in the Cl...
# 34      53  Guts: The True Stories behind Hatchet and the ...
# 35      54                      Molly Hatchet - 5 of the Best
# 36      55     Hatchet Jobs: Writings on Contemporary Fiction
# 37      57  A Changeling for All Seasons (Changeling Seaso...
# 38      58                        Changeling (Changeling  #1)
# 39      59                                 The Changeling Sea
# 40      61                                     The Changeling
# 41      63                                     The Changeling
# 42      66         The Changeling (Daughters of England  #15)
# 43      67                                    The Known World
# 44      68                                    The Known World
# 45      69                                    The Known World
# 46      71  Traders  Guns & Money: Knowns and Unknowns in ...
# 47      72             Artesia: Adventures in the Known World
# 48      73                                    The Known World
# 49      74    The John McPhee Reader (John McPhee Reader  #1)
#
#                                               authors  average_rating  \
# 0                          J.K. Rowling-Mary GrandPré            4.56
# 1                          J.K. Rowling-Mary GrandPré            4.49
# 2                          J.K. Rowling-Mary GrandPré            4.47
# 3                                        J.K. Rowling            4.41
# 4                          J.K. Rowling-Mary GrandPré            4.55
# 5                          J.K. Rowling-Mary GrandPré            4.78
# 6                              W. Frederick Zimmerman            3.69
# 7                                        J.K. Rowling            4.73
# 8                                       Douglas Adams            4.38
# 9                                       Douglas Adams            4.38
# 10                                      Douglas Adams            4.22
# 11                          Douglas Adams-Stephen Fry            4.22
# 12                                      Douglas Adams            4.38
# 13                        Bill Bryson-William Roberts            4.20
# 14                                        Bill Bryson            3.43
# 15                                        Bill Bryson            3.88
# 16                                        Bill Bryson            4.07
# 17                                        Bill Bryson            3.90
# 18                                        Bill Bryson            3.83
# 19                                        Bill Bryson            3.87
# 20                                        Bill Bryson            3.92
# 21                                        Bill Bryson            3.94
# 22                                     J.R.R. Tolkien            4.59
# 23                                     J.R.R. Tolkien            4.49
# 24                                     J.R.R. Tolkien            4.49
# 25                                     J.R.R. Tolkien            4.35
# 26                           J.R.R. Tolkien-Alan  Lee            4.49
# 27      Chris   Smith-Christopher  Lee-Richard Taylor            4.53
# 28                                        Jude Fisher            4.50
# 29                                     J.R.R. Tolkien            4.49
# 30                            James Hamilton-Paterson            3.61
# 31  Dave Thomas-David Heinemeier Hansson-Leon Bree...            3.89
# 32                                       Gary Paulsen            3.70
# 33     Donna Ickes-Edward Sciranko-Keith Vasconcelles            3.97
# 34                                       Gary Paulsen            3.87
# 35                                      Molly Hatchet            4.33
# 36                                          Dale Peck            3.48
# 37  Angela Knight-Sahara Kelly-Judy Mays-Marteeka ...            3.75
# 38                                      Delia Sherman            3.60
# 39                               Patricia A. McKillip            4.07
# 40                              Zilpha Keatley Snyder            4.17
# 41                                       Kate Horsley            3.56
# 42                                      Philippa Carr            3.99
# 43                                    Edward P. Jones            3.83
# 44                      Edward P. Jones-Kevin R. Free            3.83
# 45                                    Edward P. Jones            3.83
# 46                                       Satyajit Das            3.83
# 47                                        Mark Smylie            4.16
# 48                                    Edward P. Jones            3.83
# 49                        John McPhee-William Howarth            4.43
#
#           isbn         isbn13 language_code  # num_pages  ratings_count  \
# 0   0439785960  9780439785969           eng          652        1944099
# 1   0439358078  9780439358071           eng          870        1996446
# 2   0439554934  9780439554930           eng          320        5629932
# 3   0439554896  9780439554893           eng          352           6267
# 4   043965548X  9780439655484           eng          435        2149872
# 5   0439682584  9780439682589           eng         2690          38872
# 6   0976540606  9780976540601         en-US          152             18
# 7   0439827604  9780439827607           eng         3342          27410
# 8   0517226952  9780517226957           eng          815           3602
# 9   0345453743  9780345453747           eng          815         240189
# 10  1400052920  9781400052929           eng          215           4416
# 11  0739322206  9780739322208           eng            6           1222
# 12  0517149257  9780517149256         en-US          815           2801
# 13  076790818X  9780767908184           eng          544         228522
# 14  0767915062  9780767915069           eng           55           6993
# 15  0767910435  9780767910439           eng          256           2020
# 16  0767903862  9780767903868           eng          335          68213
# 17  076790382X  9780767903820           eng          304          47490
# 18  0060920084  9780060920081         en-US          299          43779
# 19  0380713802  9780380713806           eng          254          46397
# 20  0380727501  9780380727506           eng          324          76476
# 21  0380715430  9780380715435           eng          270          26672
# 22  0345538374  9780345538376           eng         1728          97731
# 23  0618517650  9780618517657           eng         1184           1670
# 24  0618346244  9780618346240           eng         1137           2819
# 25  0618346252  9780618346257           eng          398        2009749
# 26  0618260587  9780618260584         en-US         1216           1606
# 27  0618391002  9780618391004           eng          218          18934
# 28  0618510826  9780618510825           eng          224            343
# 29  0618153977  9780618153978           eng         1223            216
# 30  193337201X  9781933372013           eng          288           1214
# 31  097669400X  9780976694007           eng          558           1269
# 32  0689840926  9780689840920           eng          208         254827
# 33  1557344493  9781557344496           eng           48             35
# 34  0385326505  9780385326506           eng          144           1996
# 35  1575606240  9781575606248           eng           56              6
# 36  1595580271  9781595580276         en-US          228             99
# 37  1595962808  9781595962805           eng          304            167
# 38  0670059676  9780670059676           eng          256            957
# 39  0141312629  9780141312620           eng          137           4319
# 40  0595321801  9780595321803           eng          228           1155
# 41  1590301943  9781590301944           eng          339            295
# 42  0449146979  9780449146972           eng          369            341
# 43  0061159174  9780061159176           eng          388          28962
# 44  006076273X  9780060762735         en-US           14             50
# 45  0060749911  9780060749910           eng          576             22
# 46  0273704745  9780273704744           eng          334           1398
# 47  1932386106  9781932386103           eng          352             50
# 48  096513671X  9780965136716           eng          388             15
# 49  0374517193  9780374517199           eng          416            550
#
#     text_reviews_count
# 0                26249
# 1                27613
# 2                70390
# 3                  272
# 4                33964
# 5                  154
# 6                    1
# 7                  820
# 8                  258
# 9                 3954
# 10                 408
# 11                 253
# 12                 192
# 13                8840
# 14                 470
# 15                 124
# 16                4077
# 17                2153
# 18                2146
# 19                2127
# 20                3159
# 21                1986
# 22                1536
# 23                  91
# 24                 139
# 25               12784
# 26                 139
# 27                  43
# 28                   6
# 29                  19
# 30                 202
# 31                  59
# 32               11346
# 33                   2
# 34                 326
# 35                   0
# 36                  16
# 37                   4
# 38                 112
# 39                 289
# 40                  92
# 41                  42
# 42                  12
# 43                2576
# 44                  12
# 45                   3
# 46                  78
# 47                   4
# 48                   2
# 49                  36

# %%
#After glancing through the data, you will realize that some books have multiple authors.
#We thus want to perform analysis on each author so we have to split the authors

books['authors_list'] = 0
for i in range(len(books)):
    books['authors_list'][i] = books['authors'][i].split('-')
    
#declaring a new column to hold the number of authors a book has
books['num_author'] = [len(author_list) for author_list in books['authors_list']]
print(books['num_author'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0        2
# 1        2
# 2        2
# 3        1
# 4        2
#         ..
# 13709    2
# 13710    2
# 13711    2
# 13712    2
# 13713    1
# Name: num_author, Length: 13714, dtype: int64

# %%
#Now let's see the number of books each author has published or co-published

#creating a dictionary to hold the name of all the authors in the dataset.

author_books_dict ={}
for authors in books['authors_list']:
    for author in authors:
        if author not in author_books_dict:
            author_books_dict[author] = 0
            
#let us update the dictionary with the number of books an author has written
for authors in books['authors_list']:
    for author in authors:
        author_books_dict[author] += 1

# %%
#author_books_dict

# %%
print(len(author_books_dict))
# Out:
# 10457

# %%
#Time to visualize the number of books authors published

#Creating a dataframe out of the above dictionary
author_books_dict_df = pd.DataFrame()

author_books_dict_df['author'] = [i for i in author_books_dict]
author_books_dict_df['num_books'] = [author_books_dict[i] for i in author_books_dict]

author_books_dict_df.head()
# Out:
#                    author  num_books
# 0            J.K. Rowling         37
# 1           Mary GrandPré          8
# 2  W. Frederick Zimmerman          2
# 3           Douglas Adams         22
# 4             Stephen Fry          2

# %%
#Since most of the authors have similar number of publications, let's visualize
#the top 100 and middle 100 authors with the highest number of publications

author_books_dict_df = author_books_dict_df.sort_values(by=['num_books'], ascending=False)
author_books_dict_df = pd.concat([author_books_dict_df[:100], author_books_dict_df[-13600:-13700]])

author_books_dict_df.plot('author', 'num_books', figsize=(40,20), title='Number of Books Published by Authors', legend=False, kind='bar')

# %%
#Looking at exact number of books of some of the authors in descending order
author_books_dict_df.sort_values(by=['num_books'], ascending=False)
# Out:
#                    author  num_books
# 1524         Stephen King        151
# 487   William Shakespeare        118
# 4282      Agatha Christie         85
# 7          J.R.R. Tolkien         80
# 1920           Roald Dahl         63
# ...                   ...        ...
# 3           Douglas Adams         22
# 569          Aristophanes         22
# 310       Neal Stephenson         22
# 2354        Robert Ludlum         21
# 1767    Jorge Luis Borges         21
#
# [100 rows x 2 columns]

# %%
#Let's loook at the average number of pages each author has written or co-written
#let's crete a dictionary to hold name of each author and the number of pages of their books

authors_pages_dict = {}

for authors in books['authors_list']:
    for author in authors:
        if author not in authors_pages_dict:
            authors_pages_dict[author] = []
            
#appending the number of pages of all authors books into list.
for i in range(len(books)):
    for author in books['authors_list'][i]:
                        authors_pages_dict[author].append(books['# num_pages'][i])
                        
#authors and num of pages now in a list.

# %%
#taking the average of all the number of pages for each author

from statistics import mean

for i in authors_pages_dict:
    authors_pages_dict[i] = mean(authors_pages_dict[i])

# %%
#creating a dataframe out of the dictionary above
authors_pages_dict_df = pd.DataFrame()

authors_pages_dict_df['author'] = [i for i in authors_pages_dict]
authors_pages_dict_df['pages'] = [authors_pages_dict[i] for i in authors_pages_dict]

authors_pages_dict_df.head()
# Out:
#                    author  pages
# 0            J.K. Rowling    628
# 1           Mary GrandPré    944
# 2  W. Frederick Zimmerman    282
# 3           Douglas Adams    323
# 4             Stephen Fry    387

# %%
#Let's see the author and average number of pages in descending order.
authors_pages_dict_df.sort_values(by=['pages'], ascending=False)
# Out:
#                      author  pages
# 4798          Andreas Mayor   4211
# 9828     Joseph Wood Crutch   3400
# 9827   Frederick A. Blossom   3400
# 10332      Ronald Gottesman   2930
# 10331        Philip F. Gura   2930
# ...                     ...    ...
# 9964           Nicolas Cage      0
# 6787       Neal Barrett Jr.      0
# 6788           Martha Banta      0
# 8304            Martin Shaw      0
# 3553   Lou Diamond Phillips      0
#
# [10457 rows x 2 columns]

# %%
#Let us visualize what we have so far.

authors_pages_dict_df = authors_pages_dict_df.sort_values(by=['pages'], ascending=False)
authors_pages_dict_df = pd.concat([authors_pages_dict_df[:300], authors_pages_dict_df[-13614:-13714]])

# %%
authors_pages_dict_df.plot('author', 'pages', figsize=(40,20),title='Number of Pafes Written by Authors', legend=False, kind='bar')

# %%
import seaborn as sns

# %%
#Let's investigate the effect of number of authors co-authoring a book

#creating a dataframe for investigating the effect of number of co-authors on a book's average rating.

num_authors_rating = books[['average_rating', 'num_author']]
num_authors_rating.head()
# Out:
#    average_rating  num_author
# 0            4.56           2
# 1            4.49           2
# 2            4.47           2
# 3            4.41           1
# 4            4.55           2

# %%
#A visualization of the average rating each class of number of co-authors
num_authors_rating.groupby(['num_author']).mean().plot(kind='bar', legend=False)

# %%
#From the graph it is clear that books with less co-authors (probably 14 or less) have, averagely higher ratings
# than books with more co-authors (say 23 or 35 co-authors)

# %%
#Now let's check how number of co-authors affect the number of pages (size) of a book

#creating a dataframe for investigating the effect of number of co-authors on a book's size
num_authors_pages = books[['# num_pages', 'num_author']]
num_authors_pages.head()
# Out:
#    # num_pages  num_author
# 0          652           2
# 1          870           2
# 2          320           2
# 3          352           1
# 4          435           2

# %%
num_authors_pages.groupby(['num_author']).mean().plot(kind='bar', legend=False)

# %%
#It can be concluded from the above graph that, on the average, the more the co-authors, the larger the size of the book

# %%
#Let's look at the languages the books were written in
lang_code =(books['language_code'].unique().tolist())
print(lang_code)
print("\n")
print("Total num of languages of:", len(lang_code))
# Out:
# ['eng', 'en-US', 'spa', 'fre', 'en-GB', 'mul', 'ger', 'ara', 'por', 'grc', 'en-CA', 'enm', 'jpn', 'dan', 'zho', 'nl', 'ita', 'lat', 'srp', 'rus', 'tur', 'msa', 'swe', 'glg', 'cat', 'wel', 'heb', 'nor', 'gla', 'ale']
#
#
# Total num of languages of: 30

# %%
lang_count =books['language_code'].value_counts()
print(lang_count)
type(lang_count)
# Out:
# eng      10594
# en-US     1699
# spa        419
# en-GB      341
# ger        238
# fre        209
# jpn         64
# por         27
# mul         21
# ita         19
# zho         16
# grc         12
# en-CA        9
# rus          7
# nl           7
# swe          6
# glg          4
# tur          3
# cat          3
# enm          3
# lat          3
# ara          2
# ale          1
# wel          1
# nor          1
# heb          1
# msa          1
# dan          1
# srp          1
# gla          1
# Name: language_code, dtype: int64
# pandas.core.series.Series

# %%
lang_count_df =lang_count.T.squeeze()

# %%
lang_count_df.head(30)
# Out:
# eng      10594
# en-US     1699
# spa        419
# en-GB      341
# ger        238
# fre        209
# jpn         64
# por         27
# mul         21
# ita         19
# zho         16
# grc         12
# en-CA        9
# rus          7
# nl           7
# swe          6
# glg          4
# tur          3
# cat          3
# enm          3
# lat          3
# ara          2
# ale          1
# wel          1
# nor          1
# heb          1
# msa          1
# dan          1
# srp          1
# gla          1
# Name: language_code, dtype: int64

# %%
lang_count_df.plot(x="Language Code", y="Number of Books", kind='bar')

# %%
#From the above, most books were published in general english.

# %%
#So let us visualize how language affected rating

books.groupby("language_code")['ratings_count'].mean().plot(kind='bar')

# %%
#From the above, english books were the most rated books.

# %%
books.groupby("language_code")['text_reviews_count'].mean().plot(kind='bar')

# %%
#On the average, the text reviews count were mostly english books, 
#be it British english, american english etc.
