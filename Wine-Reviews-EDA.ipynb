# %%
import pandas as pd
wine_df1 = pd.read_csv('wine-reviews/winemag-data_first150k.csv',index_col=0)
wine_df2 = pd.read_csv('wine-reviews/winemag-data-130k-v2.csv', index_col=0)

# %%
type(wine_df1)
# Out:
# pandas.core.frame.DataFrame

# %%
wine_df1
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# ...

# %%
wine_df1.shape
# Out:
# (150930, 10)

# %%
wine_df1.describe()
# Out:
#               points          price
# count  150930.000000  137235.000000
# mean       87.888418      33.131482
# std         3.222392      36.322536
# min        80.000000       4.000000
# 25%        86.000000      16.000000
# 50%        88.000000      24.000000
# 75%        90.000000      40.000000
# max       100.000000    2300.000000

# %%
#Let's Groupby Countries and have an overview of the number of countries present in the dataset
country = wine_df1.groupby('country',as_index=False).count()

# %%
country.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'variety', 'winery'],
#       dtype='object')

# %%
country
# Out:
#                    country  description  designation  points  price  province  \
# 0                  Albania            2            0       2      2         2
# 1                Argentina         5631         3936    5631   5587      5631
# 2                Australia         4957         3347    4957   4894      4957
# 3                  Austria         3057         2654    3057   2483      3057
# 4   Bosnia and Herzegovina            4            1       4      4         4
# 5                   Brazil           25           18      25     25        25
# 6                 Bulgaria           77           51      77     77        77
# 7                   Canada          196          145     196    194       196
# 8                    Chile         5816         4917    5816   5766      5816
# 9                    China            3            1       3      3         3
# 10                 Croatia           89           60      89     83        89
# ...

# %%
#Let's see the average price of wine in the countries presented in our dataset
wine_df1.groupby('country', as_index=False)['price'].mean()
# Out:
#                    country      price
# 0                  Albania  20.000000
# 1                Argentina  20.794881
# 2                Australia  31.258480
# 3                  Austria  31.192106
# 4   Bosnia and Herzegovina  12.750000
# 5                   Brazil  19.920000
# 6                 Bulgaria  11.545455
# 7                   Canada  34.628866
# 8                    Chile  19.344780
# 9                    China  20.333333
# 10                 Croatia  23.108434
# 11                  Cyprus  15.483871
# 12          Czech Republic  18.000000
# 13                   Egypt        NaN
# 14                 England  47.500000
# 15                  France  45.619885
# 16                 Georgia  18.581395
# 17                 Germany  39.011078
# 18                  Greece  21.747706
# 19                 Hungary  44.204348
# 20                   India  13.875000
# 21                  Israel  31.304918
# 22                   Italy  37.547913
# 23                   Japan  24.000000
# ...

# %%
#Let's see the average points each country attains from wine reviews
wine_df1.groupby('country', as_index=False)['points'].mean()
# Out:
#                    country     points
# 0                  Albania  88.000000
# 1                Argentina  85.996093
# 2                Australia  87.892475
# 3                  Austria  89.276742
# 4   Bosnia and Herzegovina  84.750000
# 5                   Brazil  83.240000
# 6                 Bulgaria  85.467532
# 7                   Canada  88.239796
# 8                    Chile  86.296768
# 9                    China  82.000000
# 10                 Croatia  86.280899
# 11                  Cyprus  85.870968
# 12          Czech Republic  85.833333
# 13                   Egypt  83.666667
# 14                 England  92.888889
# 15                  France  88.925870
# 16                 Georgia  85.511628
# 17                 Germany  88.626427
# 18                  Greece  86.117647
# 19                 Hungary  87.329004
# 20                   India  87.625000
# 21                  Israel  87.176190
# 22                   Italy  88.413664
# 23                   Japan  85.000000
# ...

# %%
#Let's see the varieties of wine we have in our dataset.
varieties = wine_df1.groupby('variety',as_index=False).count()
varieties
# Out:
#                     variety  country  description  designation  points  price  \
# 0               Agiorgitiko      120          120           88     120    117
# 1                 Aglianico      317          317          239     317    259
# 2                    Aidani        1            1            1       1      1
# 3                     Airen        6            6            4       6      6
# 4                    Albana       17           17           17      17     15
# ..                      ...      ...          ...          ...     ...    ...
# 627  Zierfandler-Rotgipfler        3            3            1       3      2
# 628               Zinfandel     3799         3799         2826    3799   3794
# 629                Zlahtina        4            4            2       4      4
# 630                Zweigelt      219          219          148     219    200
# 631                 Žilavka        2            2            0       2      2
#
# ...

# %%
count
